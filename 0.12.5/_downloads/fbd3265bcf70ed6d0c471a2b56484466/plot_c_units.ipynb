# %% [markdown]
# # Units manipulation examples
#
# In this example, we show how units can be used in SpectroChemPy

# %%
import spectrochempy as scp

# %% [markdown]
# SpectroChemPy can do calculations with units. It uses
# [pint](https://pint.readthedocs.io) to define and perform operations on
# data with units.

# %% [markdown]
# # Create quantities
#
# To create quantity, use for instance, one of the following expression:

# %%
scp.Quantity("10.0 cm^-1")

# %%
scp.Quantity(1.0, "cm^-1/hour")

# %% [markdown]
# Or, more simply, using `ur`:

# %%
ur = scp.ur
10.0 * ur.meter / ur.gram / ur.volt

# %% [markdown]
# `ur` stands for **unit registry**, which handles many types of units and
# conversions between them.

# %% [markdown]
# # Units for dataset
#
# When loading experimental dataset using the `read` method, units are
# generally attributed to coordinates and data

# %%
ds = scp.read("wodger.spg")[0]
_ = ds.plot()

# %% [markdown]
# -   `wavenumbers` (`x` ) coordinates are here expressed in
#     $\mathrm{cm}^{-1}$
# -   and `data` are in absorbance ($\mathrm{a.u.}$) units.

# %% [markdown]
# # Convert between units
#
# Here are some examples

# %%
x = 36 * ur("km/hr")
x.to("cm/s")

# %% [markdown]
# We can make the conversion *inplace* using *ito* instead of *to*

# %%
x.ito("m/s")
x

# %% [markdown]
# Obviously you cannot convert between incompatible units

# %%
try:
    x.to("hour")
except Exception as e:
    scp.error_(scp.DimensionalityError, "Expected incompatible-unit conversion error")

# %% [markdown]
# This, of course, also applies to `NDDataset`. Let\'s try the `x`
# coordinate. It is a wavenumber expressed in $\mathrm{cm}^{-1}$ that can
# be converted to $\mathrm{THz}$, for instance:

# %%
ds.x.ito("terahertz")
_ = ds.plot()

# %% [markdown]
# We can also change wavenumber or frequency units to energy or
# wavelength, as SpectroChemPy, thanks to
# [pint](https://pint.readthedocs.io), knows how to make the
# transformation.

# %%
ds.x.ito("eV")
_ = ds.plot()

# %%
ds.x = ds.x.to("nanometer")
ds.x

# %%
_ = ds.plot()

# %% [markdown]
# `absorbance` units (the units of the data) can also be transformed into
# `transmittance`

# %%
ds.ito("transmittance")
_ = ds.plot()

# %% [markdown]
# Back to `absorbance`.

# %%
ds.ito("absorbance")
ds.x.ito("cm^-1")
_ = ds.plot()

# %%
# Uncomment the following line to display all figures when running the script
# directly with Python.
#
# scp.show()
