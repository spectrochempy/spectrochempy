# %% [markdown]
# # Project management
#
# from pathlib import Path

# %%
from spectrochempy import NDDataset
from spectrochempy import Project
from spectrochempy import pathclean
from spectrochempy import preferences as prefs
# Out:
#
#     <div>
#     <table>
#     <tr>
#     <td>
#
#     <img src='...'
#          style='height:25px; border-radius:12px; display:inline-block; float:left; vertical-align:middle'>
#     </img>
#
#     </td>
#     <td>
#
#     &nbsp;&nbsp;<span style='font-size:12px'>SpectroChemPy's API - v.0.6.11.dev80<br/>© Copyright 2014-2025 - A.Travert & C.Fernandez @ LCS</span>
#
#     </td>
#     </tr>
#     </table>
#     </div>

# %% [markdown]
# ## Project creation
# We can easily create a new project to store various datasets

# %%
proj = Project()

# %% [markdown]
# As we did not specify a name, a name has been attributed automatically:

# %%
proj.name
# Out:
# 'Project-Project_50744988'

# %% [markdown]
# ------
# To get the signature of the object, one can use the usual '?'. Uncomment the following line to check

# %%
# Project?

# %% [markdown]
# ----
# Let's change this name

# %%
proj.name = "myNMRdata"
proj
# Out:
# Project&nbsp;myNMRdata:<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;(empty&nbsp;project)

# %% [markdown]
# Now we will add a dataset to the project.
#
# First we read the dataset (here some NMR data) and we give it some name (e.g. 'nmr n°1')

# %%
datadir = pathclean(prefs.datadir)
path = datadir / "nmrdata" / "bruker" / "tests" / "nmr"
nd1 = NDDataset.read_topspin(
    path / "topspin_1d", expno=1, remove_digital_filter=True, name="NMR_1D"
)
nd2 = NDDataset.read_topspin(
    path / "topspin_2d", expno=1, remove_digital_filter=True, name="NMR_2D"
)
# Out:
#  WARNING | (UserWarning) (196608,)cannot be shaped into(147, 1024)

# %% [markdown]
# To add it to the project, we use the `add_dataset` function for a single dataset:

# %%
proj.add_datasets(nd1)

# %% [markdown]
# or `add_datasets` for several datasets.

# %%
proj.add_datasets(nd1, nd2)

# %% [markdown]
# Display its structure

# %%
proj
# Out:
# Project&nbsp;myNMRdata:<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;⤷&nbsp;NMR_1D&nbsp;(dataset)<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;⤷&nbsp;NMR_2D&nbsp;(dataset)

# %% [markdown]
# It is also possible to add other projects as sub-project (using the `add_project` )

# %% [markdown]
# ## Remove an element from a project

# %%
proj.remove_dataset("NMR_1D")
proj
# Out:
# Project&nbsp;myNMRdata:<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;⤷&nbsp;NMR_2D&nbsp;(dataset)

# %% [markdown]
# ## Get project's elements

# %%
proj.add_datasets(nd1, nd2)
proj
# Out:
# Project&nbsp;myNMRdata:<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;⤷&nbsp;NMR_1D&nbsp;(dataset)<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;⤷&nbsp;NMR_2D&nbsp;(dataset)

# %% [markdown]
# We can just use the name of the element as a project attribute.

# %%
proj.NMR_1D
# Out:
# NDDataset: [complex128] pp (size: 12411)

# %%
_ = proj.NMR_1D.plot()

# %% [markdown]
# However, this work only if the name contains no space, dot, comma, colon, etc.
# The only special character allowed is
# the underscore `_` .  If the name is not respecting this, then it is possible to use
# the following syntax (as a
# project behave as a dictionary). For example:

# %%
proj["NMR_1D"].data
# Out:
# array([1.08e+03-1.04e+03j, 2.28e+03-2.2e+03j, ...,    0.234+0.062j,   -0.101-0.0527j], shape=(12411,))

# %%
proj.NMR_2D
# Out:
# NDDataset: [quaternion] pp (shape: (y:96, x:948))

# %% [markdown]
# ## Saving and loading projects

# %%
proj
# Out:
# Project&nbsp;myNMRdata:<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;⤷&nbsp;NMR_1D&nbsp;(dataset)<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;⤷&nbsp;NMR_2D&nbsp;(dataset)

# %% [markdown]
# #### Saving

# %%
proj.save_as("NMR")
# Out:
# PosixPath('/home/runner/work/spectrochempy/spectrochempy/docs/sources/userguide/objects/project/NMR.pscp')

# %% [markdown]
# #### Loading

# %%
proj2 = Project.load("NMR")

# %%
proj2
# Out:
# Project&nbsp;NMR:<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;⤷&nbsp;NMR_1D&nbsp;(dataset)<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;⤷&nbsp;NMR_2D&nbsp;(dataset)

# %%
_ = proj2.NMR_1D.plot()

# %%
proj2.NMR_2D
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/micromamba/envs/scpy_docs/lib/python3.12/site-packages/IPython/core/formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File ~/micromamba/envs/scpy_docs/lib/python3.12/site-packages/spectrochempy/core/dataset/baseobjects/ndarray.py:857, in NDArray._repr_html_(self)
#     856 def _repr_html_(self):
# --> 857     return convert_to_html(self)
#
# File ~/micromamba/envs/scpy_docs/lib/python3.12/site-packages/spectrochempy/utils/print.py:112, in convert_to_html(obj)
#     102 tr = (
#     103     "<tr>"
#     104     "<td style='padding-right:5px; padding-bottom:0px; "
#    (...)
#     107     "padding-top:0px; {2} '>{1}</td><tr>\n"
#     108 )
#     110 obj._html_output = True
# --> 112 out = obj._cstr()
#     114 regex = r"\0{3}[\w\W]*?\0{3}"
#     116 # noinspection PyPep8
#
# File ~/micromamba/envs/scpy_docs/lib/python3.12/site-packages/spectrochempy/core/dataset/nddataset.py:592, in NDDataset._cstr(self)
#     588 out += f"       author: {self.author}\n"
#     589 out += f"      created: {self.created}\n"
#     590 out += (
#     591     f"     modified: {self.modified}\n"
# --> 592     if (self._modified - self._created).seconds > 30
#     593     else ""
#     594 )
#     596 wrapper1 = textwrap.TextWrapper(
#     597     initial_indent="",
#     598     subsequent_indent=" " * 15,
#     599     replace_whitespace=True,
#     600     width=self._text_width,
#     601 )
#     603 pars = self.description.strip().splitlines()
#
# TypeError: can't subtract offset-naive and offset-aware datetimes
# NDDataset: [quaternion] pp (shape: (y:96, x:948))

# %%
_ = proj.NMR_2D.plot()
