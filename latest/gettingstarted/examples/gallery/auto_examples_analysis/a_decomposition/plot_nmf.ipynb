# %% [markdown]
# # NMF analysis example

# %% [markdown]
# Import the spectrochempy API package

# %%
import spectrochempy as scp
# Out:
#
#     <div>
#     <table>
#     <tr>
#     <td>
#
#     <img src='...'
#          style='height:25px; border-radius:12px; display:inline-block; float:left; vertical-align:middle'>
#     </img>
#
#     </td>
#     <td>
#
#     &nbsp;&nbsp;<span style='font-size:12px'>SpectroChemPy's API - v.0.6.11.dev5<br/>© Copyright 2014-2025 - A.Travert & C.Fernandez @ LCS</span>
#
#     </td>
#     </tr>
#     </table>
#     </div>

# %% [markdown]
# # Prepare the dataset to NMF factorize

# %% [markdown]
# Here we use a FTIR dataset corresponding the dehydration of a NH4Y
# zeolite and recorded in the OMNIC format.

# %%
dataset = scp.read_omnic("irdata/nh4y-activation.spg")

# %% [markdown]
# Mask some columns (features) wich correspond to saturated part of the
# spectra. Note taht we use float number for defining the limits for
# masking as coordinates (integer numbers would mean point index and s
# would lead t incorrect results)

# %%
dataset[:, 882.0:1280.0] = scp.MASKED

# %% [markdown]
# Make sure all data are positive. For this we use the math
# fonctionalities of NDDataset objects (`min`{.interpreted-text
# role="meth"} function to find the minimum value of the dataset and the
# [-]{.title-ref} operator for subtrating this value to all spectra of the
# dataset.

# %%
dataset -= dataset.min()

# %% [markdown]
# Plot it for a visual check

# %%
_ = dataset.plot()

# %% [markdown]
# # Create a NMF object
#
# As argument of the object constructor we define log_level to `"INFO"` to
# obtain verbose output during fit, and we set the number of component to
# use at 4.

# %%
model = scp.NMF(n_components=4, log_level="INFO")

# %% [markdown]
# # Fit the model

# %%
_ = model.fit(dataset)

# Get the results
# ---------------
#
# The concentration :math:`C` and the transposed matrix of spectra :math:`S^T` can
# be obtained as follow
C = model.transform()
St = model.components
# Out:
#  WARNING | (ConvergenceWarning) Maximum number of iterations 200 reached. Increase it to improve convergence.
# violation: 1.0
# violation: 0.14017421024501964
# violation: 0.061581950654932376
# violation: 0.034777744528724966
# violation: 0.02315591268977666
# violation: 0.016289564836607366
# violation: 0.011732197722809682
# violation: 0.00926117915319006
# violation: 0.007770502529914441
# violation: 0.0069574716101589995
# violation: 0.00645741437035495
# violation: 0.006191115125282101
# violation: 0.0060572389744578264
# violation: 0.006000777806339307
# violation: 0.005868357891308719
# violation: 0.005802918028533955
# violation: 0.0057723676588298635
# violation: 0.005756947971778051
# violation: 0.005733332889918931
# violation: 0.005700606624644739
# violation: 0.005667827078790757
# violation: 0.005587736630048308
# violation: 0.0055291351831669505
# violation: 0.00546076067407584
# violation: 0.00537519467345171
# violation: 0.005288054442075067
# violation: 0.005203284939611627
# violation: 0.005110269931845539
# violation: 0.005004969613317298
# violation: 0.004889401944567251
# violation: 0.004778610916794585
# violation: 0.004657040705272516
# violation: 0.004527642308383291
# violation: 0.00439371747717498
# violation: 0.00426712413892573
# violation: 0.00413392813301608
# violation: 0.004012755928138814
# violation: 0.003891465351926661
# violation: 0.0037652602700428005
# violation: 0.0036375148218628917
# violation: 0.0035147101661545882
# violation: 0.0033965138303581077
# violation: 0.0032925205579806094
# violation: 0.0031941648132722197
# violation: 0.0005549930907515556
# violation: 0.0005526263090685627
# violation: 0.0005503237863509389
# violation: 0.0005480875748007858
# violation: 0.0005458976082894267
# violation: 0.0005437570853968874
# violation: 0.0005416726314730198
# violation: 0.0005396329582221765
# violation: 0.0005376381718605749
# violation: 0.0005358628850810474
# violation: 0.000534256644634617
# violation: 0.0005327134944358506
# violation: 0.0005311700256178639
# violation: 0.0005296374901747557
# violation: 0.0005281469649348514
# violation: 0.0005266549474162502
# violation: 0.000525186071889515
# violation: 0.0005237318107590732
# violation: 0.0005222955570668339
# violation: 0.0005208942964237717
# violation: 0.0005195265168841826
# violation: 0.0005181813428114981
# violation: 0.0005168846752736575
# violation: 0.0005156608680270679
# violation: 0.0005144616554311679
# violation: 0.000513289168818843
# violation: 0.0005121515266402634
# violation: 0.0005110364330892806
# violation: 0.0005099447315065555
# violation: 0.0005088753613794654
# violation: 0.0005078236610580307
# violation: 0.0005067909112022117
# violation: 0.0005057740763561446
# violation: 0.0005047767175614131
# violation: 0.0005037958933651659
# violation: 0.0005028222129278678
# violation: 0.000501865042847973
# violation: 0.0005009224423800065
# violation: 0.0004999974962489141
# violation: 0.0004990872395198222
# violation: 0.0004981962000751801
# violation: 0.0004973147318187666
# violation: 0.0004964417296739769
# violation: 0.0004955753197884885
# violation: 0.0004946901218456832
# violation: 0.000493821043730555
# violation: 0.0004929673596846598
# violation: 0.0004921226355843696
# violation: 0.0004912871202795722
# violation: 0.0004904596528540816
# violation: 0.000489637645653118
# violation: 1.0
# violation: 0.27811881011285766
# violation: 0.211038392734424
# violation: 0.16365897573755164
# violation: 0.12638124502857312
# violation: 0.09689398092857929
# violation: 0.07386553913526347
# violation: 0.05726304883639109
# violation: 0.04639710696895078
# violation: 0.037762701010723945
# violation: 0.030324671559647968
# violation: 0.024000077998569205
# violation: 0.018705054318854972
# violation: 0.014282427091627565
# violation: 0.010676123451468351
# violation: 0.00801653482738566
# violation: 0.0062386161148282
# violation: 0.005124394633030091
# violation: 0.004490757479656489
# violation: 0.004053115751123404
# violation: 0.003744302603668862
# violation: 0.0034289628116608685
# violation: 0.0030323190347559077
# violation: 0.0027272537391467523
# violation: 0.0023865056940470114
# violation: 0.002085162862784034
# violation: 0.0017697484695161968
# violation: 0.0014925716272856926
# violation: 0.0012488601974044579
# violation: 0.0010438675111377118
# violation: 0.0008573236692761724
# violation: 0.0006991377766200465
# violation: 0.0005706218431927033
# violation: 0.0004636286240955179
# violation: 0.0003748723547989671
# violation: 0.00030325790844269496
# violation: 0.00024636638593841554
# violation: 0.00019825804790407232
# violation: 0.00015827733519296793
# violation: 0.0001243907579281539
# violation: 9.611089606617979e-05
# Converged at iteration 42

# %% [markdown]
# # Plot results

# %%
_ = C.T.plot(title="Concentration", colormap=None, legend=C.k.labels)

# %%
m = St.ptp()
for i in range(St.shape[0]):
    St.data[i] -= i * m / 2
ax = St.plot(title="Components", colormap=None, legend=St.k.labels)
ax.set_yticks([])
# Out:
# []

# %% [markdown]
# This ends the example ! The following line can be uncommented if no plot
# shows when running the .py script with python

# %%
# scp.show()
