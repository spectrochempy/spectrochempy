# %% [markdown]
# # Processing of the TGA data

# %%
from spectrochempy.api import *
options.log_level = WARN
import os
# Out:
#         SpectroChemPy's API
#         Version   : 0.1a3.post1
#         Copyright : 2014-2017 - LCS (Laboratory for Catalysis and Spectrochempy)

# %% [markdown]
# Our TGA data are in our test `scpdata` directory and have been stored in a file with extension `scp`

# %%
samples = {'P350':{'label':'$\mathrm{M_P}\,(623\,K)$'},
           'A350':{'label':'$\mathrm{M_A}\,(623\,K)$'}, 
           'B350':{'label':'$\mathrm{M_B}\,(623\,K)$'}}

for key in samples.keys():
    basename = os.path.join(scpdata,'agirdata/{}/TGA/tg'.format(key))
    filename = basename + '.scp'
    samples[key]['TGA'] = NDDataset.read( filename)

# %% [markdown]
# ## Initial corrections of the TG data.
#
# We are interested by the gain in weight during the reaction. But, the zero in time is obviously not the same for all three samples.
#
# We will now correct this.

# %%
#options.log_level=DEBUG
figure()
# we will plot on the same figure
colors = [NBlack, NBlue, NRed]
markers = ['o','s','^']
for i, key in enumerate(samples.keys()):
    s = samples[key]['TGA']
    s.plot_scatter(ylim=(-.1,9), lines=True, m=markers[i], c=colors[i], ms=7, me=50)
label = samples[key]['label']
title = 'TG data (623 K)'
s.ax.set_title(title, fontsize=16)
show()
# Out:
# <img src="data:image/png;base64,..." width="680">

# %%
z={'SP350':2,
   'SA350':9,
   'SB350':0,
